# %% [markdown]
# #                                My jupyter notebook
# ## Add an iamge uning image link

# %% [markdown]
# <img src=
# "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQe9UcsgVeuGoXRdLRXB5l0kGN5aSWJTbVoKA&usqp=CAU">

# %% [markdown]
# ## Add a youtube link on stock

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7EUbrFLef7M" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7EUbrFLef7M" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Extracting data from search engine

# %%
from pandas_datareader import data as pd
df = pd.DataReader('AAPL', 'yahoo', '2019/1/1', '2020/1/1')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2018-12-31  39.840000  39.119999  39.632500  39.435001  140014000.0  38.461140
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0  38.505024
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0  34.669640
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0  36.149662
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0  36.069202

# %% [markdown]
# # Drawing an inline plot

# %%
# %matplotlib inline
df.plot(y='Close', color="green")

# %% [markdown]
# # Drawing a bar chart

# %%
df.plot.bar(y='Volume')
